# %% [markdown]
# <a href="https://colab.research.google.com/github/roddens/KrisRoddenProjects/blob/master/TF_WS_Data_Vis_portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #Numpy provides fast mathematical function processing
import pandas as pd #Pandas is used for easy indexing and data collection tools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#datafram is named "military_spending"
military_spending=pd.read_csv("https://raw.githubusercontent.com/roddens/TF-WS-Data-Vis-samples/master/Military%20Expenditure.csv")

# %%
#This previews the data
military_spending.head()

# %%
#gives a list of column names
military_spending.columns.values

# %%
#gives size of data have uploaded
military_spending.shape

# %%
#presents all of the data
military_spending

# %%
military_spending.plot

# %%
#Rename DF to not overwrite original
#Execute code
#Pick 2 cols
military_spending2 = military_spending.plot.bar(x='Name', y="2018")
plt.title("Bar Plot")
plt.xlabel("Country Name")
plt.ylabel("1960 military spending, in millions")
plt.rcParams['figure.figsize']={100,10}
plt.show
# Out:
# <function matplotlib.pyplot.show>
